# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\S Das\Downloads\covid_sample_data.csv")
df.dropna()
# Out:
#           Date Country  Confirmed Deaths  Recovered
# 0   01-01-2020   India        1.0      0        0.0
# 2   03-01-2020   India        7.0      1        2.0
# 4   05-01-2020   India       50.0      2       15.0
# 7   08-01-2020   India      300.0      7      120.0
# 8   09-01-2020   India      600.0     10      300.0
# 10  01-01-2020     USA        2.0      0        0.0
# 13  04-01-2020     USA       25.0      1       10.0
# 15  06-01-2020     USA      100.0      2       35.0
# 19  10-01-2020     USA     1500.0     13      700.0

# %%
df.sort_values('Recovered', ascending=False)
# Out:
#           Date Country  Confirmed Deaths  Recovered
# 19  10-01-2020     USA     1500.0     13      700.0
# 9   10-01-2020   India        NaN     15      600.0
# 8   09-01-2020   India      600.0     10      300.0
# 17  08-01-2020     USA      400.0    NaN      160.0
# 7   08-01-2020   India      300.0      7      120.0
# 15  06-01-2020     USA      100.0      2       35.0
# 5   06-01-2020   India        NaN      3       30.0
# 14  05-01-2020     USA       60.0    NaN       20.0
# 4   05-01-2020   India       50.0      2       15.0
# 13  04-01-2020     USA       25.0      1       10.0
# 3   04-01-2020   India        NaN      1        5.0
# 12  03-01-2020     USA        NaN      0        3.0
# 2   03-01-2020   India        7.0      1        2.0
# 11  02-01-2020     USA        5.0    NaN        1.0
# 0   01-01-2020   India        1.0      0        0.0
# 10  01-01-2020     USA        2.0      0        0.0
# 1   02-01-2020   India        3.0      0        NaN
# ...

# %%
df[(df['Confirmed'] > 100) & (df['Recovered'] > 100)]
# Out:
#           Date Country  Confirmed Deaths  Recovered
# 7   08-01-2020   India      300.0      7      120.0
# 8   09-01-2020   India      600.0     10      300.0
# 17  08-01-2020     USA      400.0    NaN      160.0
# 19  10-01-2020     USA     1500.0     13      700.0

# %%
df.iloc[10:100]
# Out:
#           Date Country  Confirmed Deaths  Recovered
# 10  01-01-2020     USA        2.0      0        0.0
# 11  02-01-2020     USA        5.0    NaN        1.0
# 12  03-01-2020     USA        NaN      0        3.0
# 13  04-01-2020     USA       25.0      1       10.0
# 14  05-01-2020     USA       60.0    NaN       20.0
# 15  06-01-2020     USA      100.0      2       35.0
# 16  07-01-2020     USA        NaN      4        NaN
# 17  08-01-2020     USA      400.0    NaN      160.0
# 18  09-01-2020     USA      900.0      9        NaN
# 19  10-01-2020     USA     1500.0     13      700.0
# 20         NaN     NaN        NaN    NaN        NaN

# %%
df.groupby('Country')['Recovered'].agg(['sum', 'mean', 'median', 'max'])
# Out:
#             sum     mean  median    max
# Country
# India    1072.0  134.000    22.5  600.0
# USA       929.0  116.125    15.0  700.0

# %% [markdown]
# ### Bar Chart - Sales by Region

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample sales data
data = {
    'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West'],
    'Sales': [2500, 3000, 1800, 2200, 2700, 3100, 1900, 2300]
}

# Create DataFrame
df = pd.DataFrame(data)

# Group by region and sum sales
region_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)

# Plot using matplotlib
plt.figure(figsize=(8, 5))
region_sales.plot(kind='bar', color='skyblue')

plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
